# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
from matplotlib.pyplot import specgram
# Out:
# /home/therochvoices/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/therochvoices/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
import os

# %%
files = os.listdir('RawData/')

# %%
data1, sampling_rate1 = librosa.load("data/Actor_01/03-02-01-01-01-01-01.wav")
data2, sampling_rate2 = librosa.load("data/Actor_02/03-02-01-01-01-01-02.wav")
data3, sampling_rate3 = librosa.load("data/Actor_03/03-02-01-01-01-01-03.wav")
data4, sampling_rate4 = librosa.load("data/Actor_04/03-02-01-01-01-01-04.wav")

data5, sampling_rate5 = librosa.load("data/Actor_05/03-02-01-01-01-01-05.wav")
data6, sampling_rate6 = librosa.load("data/Actor_06/03-02-01-01-01-01-06.wav")
data7, sampling_rate7 = librosa.load("data/Actor_07/03-02-01-01-01-01-07.wav")
data8, sampling_rate8 = librosa.load("data/Actor_08/03-02-01-01-01-01-08.wav")
data9, sampling_rate9 = librosa.load("data/Actor_09/03-02-01-01-01-01-09.wav")
data10, sampling_rate10 = librosa.load("data/Actor_10/03-02-01-01-01-01-10.wav")
data11, sampling_rate11 = librosa.load("data/Actor_11/03-02-01-01-01-01-11.wav")
data12, sampling_rate12 = librosa.load("data/Actor_12/03-02-01-01-01-01-12.wav")

# %%
plt.figure(figsize=(15, 5))
librosa.display.waveplot(data1, sr=sampling_rate1)
librosa.display.waveplot(data3, sr=sampling_rate3)
librosa.display.waveplot(data5, sr=sampling_rate5)
librosa.display.waveplot(data7, sr=sampling_rate7)
librosa.display.waveplot(data9, sr=sampling_rate9)
librosa.display.waveplot(data11, sr=sampling_rate11)
plt.show()

plt.figure(figsize=(15, 5))
librosa.display.waveplot(data2, sr=sampling_rate2)
librosa.display.waveplot(data4, sr=sampling_rate4)
librosa.display.waveplot(data6, sr=sampling_rate6)
librosa.display.waveplot(data8, sr=sampling_rate8)
librosa.display.waveplot(data10, sr=sampling_rate10)
librosa.display.waveplot(data12, sr=sampling_rate12)
plt.show()

# %%
plt.figure(figsize=(15, 5))
librosa.display.waveplot(data1, sr=sampling_rate1)
librosa.display.waveplot(data5, sr=sampling_rate5)

# %%
emotion1, sampling1 = librosa.load("data/Actor_01/03-02-01-01-01-01-01.wav")
emotion2, sampling2 = librosa.load("data/Actor_01/03-02-02-01-01-01-01.wav")
emotion3, sampling3 = librosa.load("data/Actor_01/03-02-03-01-01-01-01.wav")
emotion4, sampling4 = librosa.load("data/Actor_01/03-02-04-01-01-01-01.wav")
emotion5, sampling5 = librosa.load("data/Actor_01/03-02-05-01-01-01-01.wav")
emotion6, sampling6 = librosa.load("data/Actor_01/03-02-06-01-01-01-01.wav")

# %% [markdown]
# # Plots representing differences in amplitudes when same sentence is spoken but with different emotions

# %%
plt.figure(figsize=(15, 2))
#librosa.display.waveplot(emotion1, sr=sampling1, color='blue')
#librosa.display.waveplot(emotion2, sr=sampling2, color='red')
librosa.display.waveplot(emotion3, sr=sampling3, color='yellow')
librosa.display.waveplot(emotion4, sr=sampling4, color='green')
plt.title("Happy(Yellow) vs Sad(Green)")
plt.show()
plt.figure(figsize=(15, 2))
librosa.display.waveplot(emotion5, sr=sampling5, color='Red')
librosa.display.waveplot(emotion1, sr=sampling1, color='Blue')
plt.title("Neutral(Blue) vs Angry(Red)")
plt.show()

plt.figure(figsize=(15, 2))
librosa.display.waveplot(emotion5, sr=sampling5, color='Red')
librosa.display.waveplot(emotion3, sr=sampling3, color='Yellow')
plt.title("Happy(Yellow) vs Angry(Red)")
plt.show()

plt.figure(figsize=(15, 2))
librosa.display.waveplot(emotion1, sr=sampling1, color='pink')
librosa.display.waveplot(emotion2, sr=sampling2, color='Magenta')
plt.title("Neutral(Pink) vs Calm(Magenta)")
plt.show()

# %% [markdown]
# # Plotting the Mel-Spectogram of the audio files

# %%
import matplotlib.pyplot as plt
import scipy.io.wavfile
import numpy as np
import sys


sr,x = scipy.io.wavfile.read('RawData/03-02-01-01-01-01-01.wav')

## Parameters: 10ms step, 30ms window
nstep = int(sr * 0.01)
nwin  = int(sr * 0.03)
nfft = nwin

window = np.hamming(nwin)

## will take windows x[n1:n2].  generate
## and loop over n2 such that all frames
## fit within the waveform
nn = range(nwin, len(x), nstep)

X = np.zeros( (len(nn), nfft//2) )

for i,n in enumerate(nn):
    xseg = x[n-nwin:n]
    z = np.fft.fft(window * xseg, nfft)
    X[i,:] = np.log(np.abs(z[:nfft//2]))

plt.imshow(X.T, interpolation='nearest',
    origin='lower',
    aspect='auto')

plt.show()
# Out:
# /home/therochvoices/.local/lib/python3.6/site-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)
# /home/therochvoices/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: RuntimeWarning: divide by zero encountered in log
