# %%
import IPython.display as ipd

# %%
import pandas as pd
import librosa
import glob
# Out:
# /home/therochvoices/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/therochvoices/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/therochvoices/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
import matplotlib.pyplot as plt

# %%
data1, s1 = librosa.load('data/Actor_01/03-02-01-01-01-01-01.wav')
data2, s2 = librosa.load('data/Actor_02/03-02-01-01-01-01-02.wav')
data3, s3 = librosa.load('data/Actor_03/03-02-01-01-01-01-03.wav')
data4, s4 = librosa.load('data/Actor_04/03-02-01-01-01-01-04.wav')
data5, s5 = librosa.load('data/Actor_05/03-02-01-01-01-01-05.wav')
data6, s6 = librosa.load('data/Actor_06/03-02-01-01-01-01-06.wav')

# %%
import librosa.display
plt.figure(figsize=(12, 4))
librosa.display.waveplot(data1, sr=s1)
librosa.display.waveplot(data2, sr=s2)
librosa.display.waveplot(data3, sr=s3)
librosa.display.waveplot(data4, sr=s4)
librosa.display.waveplot(data5, sr=s5)
librosa.display.waveplot(data6, sr=s6)
